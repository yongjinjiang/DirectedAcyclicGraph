# %%
from graphviz import Digraph
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LassoCV
import copy
from random import shuffle as sl
from random import randint as rd
from IPython.display import Image

# %%
# 1st step: generate the directed acyclic graph
n = 20   #number of nodes
m = 20   #number of directed edges 

def gn():
    num = rd(1,1000)
    return num
def w2f(f,num,fg):
    f.write(str(num))
    if fg==True:
        f.write('\n')
    else:
        f.write(' ')

def DataMake(c):
   
    f = open('./data/data_{}_{}'.format(n,m)+"__"+str(c)+'.txt','w')
    
    node = list(range(1,n+1))
    sl(node)
    sl(node)
    
    w2f(f,n,0);w2f(f,m,1)
    edges=[]
    count=0
    while count<m:
        p1 = rd (1,n-1)
        p2 = rd (p1+1,n)
        x = node[p1-1]
        y = node[p2-1]
        if [x,y] not in edges:
            edges.append([x,y])
            w2f(f,x,0);w2f(f,y,1);
            count+=1
    print(n,' node',m,' edges')
    f.close()

# %%
# prepare data file for the DAG
c=1
DataMake(c)
print('Done')
# Out:
# 20  node 20  edges
# Done

# %%
#2nd step: visualize the graph(which is saved in fsm.gv.pdf). return a mat describing the graph structure
def vis_mat(c,n,m):
    f = Digraph('finite_state_machine', filename='fsm.gv')
    with f.subgraph() as s:
        s.attr(rank='same')
        f.attr('node', shape='circle')
        for i in range(n):
            f.node(str(i))

    # f.attr(rankdir='LR', size='8,5')

    file1 = open('./data/data_{}_{}'.format(n,m)+"__"+str(c)+'.txt',"r")  
    n,m=[int(x) for x in file1.readline().split()]

    f.attr('node', shape='circle')
    for i in range(n):
        f.node(str(i))

    mat=np.zeros([n]*2)
    f.attr('node', shape='circle')    
    for i in range(m):
        i,j=[int(x) for x in file1.readline().split()]
        f.edge(str(i-1), str(j-1))
        mat[j-1,i-1]=1
    #     print(i,j)

    f.view()    
    return mat

def only_mat(c,n,m):
    file1 = open('data_{}_{}'.format(n,m)+"__"+str(c)+'.txt',"r")  
    n,m=[int(x) for x in file1.readline().split()]
    mat=np.zeros([n]*2)
      
    for i in range(m):
        i,j=[int(x) for x in file1.readline().split()] 
        mat[j-1,i-1]=1
    return mat

# %%
#run the function and see the graph structure in the fsm.gv.pdf file. The mat matrix would be used later.
mat=vis_mat(c,n,m)

# %%
#prepare two dicts for later use. Generate the topological order of the nodes in DAG
def structure_data(mat):
    dic=dict()  #dict(key:node, value: list of the node's chidren)
    for j in range(n):
          s=dic.setdefault(str(j),[]);
          for i in range(n):
            if mat[i,j]!=0:
                dic[str(j)].append(i)
    print("children_dic:")
    print(dic)

    parents_dic=dict()  #dict(key:node, value:list of the node's parents)
    for i in range(n):
          s=parents_dic.setdefault(str(i),[]);
          for j in range(n):
            if mat[i,j]!=0:
                parents_dic[str(i)].append(j)

    print("parents_dic:")
    print(parents_dic)

    nodes=range(n)
    #generate topological order of the nodes(note topological order is not unique to a given directed acyclic graph)
    top_list=[]

    def child(j):
        while dic[str(j)] != [] and not set(dic[str(j)]).issubset(set(top_list)):
            for i in dic[str(j)]:
                while dic[str(i)] !=[] and not set(dic[str(i)]).issubset(set(top_list)):   
                    child(i)
                else:
                    if  i not in top_list: 
                        top_list.append(i)
    #                     print("top_list=",top_list)
        else:
            if j not in top_list:
                top_list.append(j)
    #             print("top_list=",top_list)

    for j in nodes:
         child(j)

    print('topological order of the nodes:')
    print(top_list)
    return dic, parents_dic, top_list

dic, parents_dic, top_list=structure_data(mat)
# Out:
# children_dic:
# {'0': [], '1': [4], '2': [1], '3': [6, 12], '4': [6], '5': [6], '6': [], '7': [19], '8': [0], '9': [2, 4, 8], '10': [6, 8], '11': [6], '12': [1], '13': [10], '14': [5], '15': [], '16': [], '17': [], '18': [9], '19': [11, 12]}
# parents_dic:
# {'0': [8], '1': [2, 12], '2': [9], '3': [], '4': [1, 9], '5': [14], '6': [3, 4, 5, 10, 11], '7': [], '8': [9, 10], '9': [18], '10': [13], '11': [19], '12': [3, 19], '13': [], '14': [], '15': [], '16': [], '17': [], '18': [], '19': [7]}
# topological order of the nodes:
# [0, 6, 4, 1, 2, 12, 3, 5, 11, 19, 7, 8, 9, 10, 13, 14, 15, 16, 17, 18]

# %%
#3rd step: Enumerate paths:  produce all directed paths connecting two nodes V_i(node_label: start) to V_j(node_label: end).
def paths_given_two_nodes(dic,top_list, start, end):
    id_start=top_list.index(start)
    id_end=top_list.index(end)
    if id_start<=id_end:
        return []
    
    def add_path(new_node,path,paths):
        if top_list.index(new_node)>id_end:
            path.append(new_node)         
        elif top_list.index(new_node)==id_end:
            path.append(new_node)
            paths.append(copy.deepcopy(path))  #deepcopy is essential here!!
#             print('1',paths)    this print statement will produce strange result!!
            path.pop()
            return path,paths
        else:
            return path,paths
        
        for nn in dic[str(new_node)]:
            path,paths=add_path(nn,path,paths) 
        path.pop()
        return path,paths
    paths=[]
    path=[]
    path,paths=add_path(start,path,paths)
    if paths!=[]:
        print("the roads connecting {}th node to {}th node are:".format(start,end))
        print(paths)
    return paths

# %%
#run 3rd step:
paths=paths_given_two_nodes(dic,top_list,18,6)
# Out:
# the roads connecting 18th node to 6th node are:
# [[18, 9, 2, 1, 4, 6], [18, 9, 4, 6]]

# %%
#4th step: Generate data according to the structure of the graph:
def generate_data(n_sample,n,parents_dic):
    Data=np.zeros((n_sample,n))
    mod1=lambda num:np.random.normal(0,1,num)

    for d in range(n_sample):
        Data[d,:]=mod1(n)  # firstly: all nodes are assigned independent random numbers with distribution N(0,1) 
        for i in range(n):
            for j in parents_dic[str(i)]:
                Data[d,i]=Data[d,i]+Data[d,j]  #for nodes with parents, the parents variables are added
    return Data
n_sample=1000
Data=generate_data(n_sample,n,parents_dic)

# %%
#5th step: 
def feature_selection(Data, target, N_selected):
    
    df=pd.DataFrame(Data)
    y=df[target]
    X = df.drop([target], axis=1)
    
    reg = LassoCV(cv=5, random_state=0).fit(X, y)
    ss1=reg.score(X, y)
    print("Rsquare score with all features:",ss1) 

    #assign very low threshold as starting point
    sfm = SelectFromModel(clf, threshold=0.0001)
    s=sfm.fit(X, y)
    X_transform = sfm.transform(X)
    n_features = X_transform.shape[1]

    # Reset the threshold till the number of features equals two.
    while n_features > N_selected:
        sfm.threshold += 0.001
        X_transform = sfm.transform(X)
        n_features = X_transform.shape[1]
    #     print("threshold=",sfm.threshold, "n_features=",n_features)

    reg = LassoCV(cv=5, random_state=0).fit(X_transform, y)
    ss2=reg.score(X_transform, y)
    print("Rsquare Score with selected features:",ss2) 

    print("n_features=",n_features)
    print("target=",target)
    a=list(sfm.get_support())
    a.insert(target,False)
    selected=[i for i in range(len(a)) if a[i]]
    print("selected=",selected)
    return selected, ss1,ss2
    
target=1
N_selected=5
selected, ss1,ss2=feature_selection(Data, target, N_selected)
# Out:
# Rsquare score with all features: 0.898034216702338
# Rsquare Score with selected features: 0.8382492458711671
# n_features= 5
# target= 1
# selected= [2, 9, 12, 13, 18]

# %% [markdown]
# ### Nice examples of feature selection(refer to the specific Graph below):
#   - for target=14,  N_selected=6,  the selected nodes are: [5, 6, 11, 15, 16]
#   - for target=17,  N_selected=4,  the selected nodes are: [3, 7, 12, 19]
#   - for target=17,  N_selected=5,  the selected nodes are: [3, 7, 9, 12, 19]
#   - for target=0,   N_selected=2,  the selected nodes are: [7,10]

# %%
fig = Image(filename=('./DAG.png'))
fig

# %% [markdown]
# ### One point on  probability distribution
# - The data distribution for each node is centered around 0,  with different variance. For example, the 1st node has a variance $\sqrt{2}$, 8th node has variance $\sqrt{3}$ while 13rd node has variance 1.

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(3,1,1)
s=ax.hist( np.array(y),bins=35 ,)
s=ax.set_ylabel("hist for node {}".format(target));

ax = fig.add_subplot(3,1,2)
s=ax.hist( np.array(X[1]),bins=35 ,)
s=ax.set_ylabel("hist for node {}".format(1));

ax = fig.add_subplot(3,1,3)
s=ax.hist( np.array(X[13]),bins=35 ,)
s=ax.set_ylabel("hist for node {}".format(13));

# %% [markdown]
# ## 6th step.
# - Now, let's generate 100 random graphs with n=20 nodes and m=20 edges. Then, calculate $R^2$ score for selected features. Based on some observations on calculated result, we would select L-distant-neighbours as features and try to see the L-dependence on the final hist-diagram.

# %%
result=[]

n=20
m=20
Ls=[1,2,3]
# c=1
for c in range(100):
    print("ccccccccccc=",c)
    DataMake(c)
    mat=only_mat(c,n,m)
    dic, parents_dic, top_list=structure_data(mat)

    # paths=paths_given_two_nodes(dic,top_list,18,6)

    n_sample=1000
    Data=generate_data(n_sample,n,parents_dic)


    def distance(i,j,dis):
        paths=paths_given_two_nodes(dic,top_list,i,j)+paths_given_two_nodes(dic,top_list,j,i)
        dis[(i,j)]=set([len(path)-1 for path in paths])
        dis[(j,i)]=set([len(path)-1 for path in paths])
        return dis

    dis=dict()
    for i in range(n):
        for j in range(i+1,n):
            dis=distance(i,j,dis)

    for L in Ls:        
        for i in range(n):
            target=i
            features=[]
            for j in list(range(i))+list(range(i+1,n)):
                if L in dis[(i,j)]:
                    features.append(j) 
            N_selected=len(features) 

            if N_selected>=2:
                selected, ss1,ss2=feature_selection(Data, target, N_selected)
                result.append((c,target,selected,N_selected,L,ss1,ss2))
# Out:
# ccccccccccc= 0
# 20  node 20  edges
# children_dic:
# {'0': [], '1': [18], '2': [], '3': [12], '4': [11], '5': [2], '6': [12], '7': [], '8': [11], '9': [2, 15], '10': [], '11': [9], '12': [], '13': [], '14': [9, 12], '15': [3, 12], '16': [3, 9, 12], '17': [11, 13], '18': [7], '19': [12]}
# parents_dic:
# {'0': [], '1': [], '2': [5, 9], '3': [15, 16], '4': [], '5': [], '6': [], '7': [18], '8': [], '9': [11, 14, 16], '10': [], '11': [4, 8, 17], '12': [3, 6, 14, 15, 16, 19], '13': [17], '14': [], '15': [9], '16': [], '17': [], '18': [1], '19': []}
# topological order of the nodes:
# [0, 7, 18, 1, 2, 12, 3, 15, 9, 11, 4, 5, 6, 8, 10, 13, 14, 16, 17, 19]
# the roads connecting 1th node to 7th node are:
# [[1, 18, 7]]
# the roads connecting 1th node to 18th node are:
# [[1, 18]]
# the roads connecting 4th node to 2th node are:
# [[4, 11, 9, 2]]
# the roads connecting 5th node to 2th node are:
# [[5, 2]]
# the roads connecting 8th node to 2th node are:
# [[8, 11, 9, 2]]
# the roads connecting 9th node to 2th node are:
# [[9, 2]]
# the roads connecting 11th node to 2th node are:
# [[11, 9, 2]]
# the roads connecting 14th node to 2th node are:
# [[14, 9, 2]]
# the roads connecting 16th node to 2th node are:
# [[16, 9, 2]]
# the roads connecting 17th node to 2th node are:
# [[17, 11, 9, 2]]
# the roads connecting 4th node to 3th node are:
# [[4, 11, 9, 15, 3]]
# the roads connecting 8th node to 3th node are:
# [[8, 11, 9, 15, 3]]
# the roads connecting 9th node to 3th node are:
# [[9, 15, 3]]
# the roads connecting 11th node to 3th node are:
# [[11, 9, 15, 3]]
# the roads connecting 3th node to 12th node are:
# [[3, 12]]
# the roads connecting 14th node to 3th node are:
# [[14, 9, 15, 3]]
# the roads connecting 15th node to 3th node are:
# [[15, 3]]
# the roads connecting 16th node to 3th node are:
# [[16, 3], [16, 9, 15, 3]]
# the roads connecting 17th node to 3th node are:
# [[17, 11, 9, 15, 3]]
# the roads connecting 4th node to 9th node are:
# [[4, 11, 9]]
# the roads connecting 4th node to 11th node are:
# [[4, 11]]
# the roads connecting 4th node to 12th node are:
# [[4, 11, 9, 15, 3, 12], [4, 11, 9, 15, 12]]
# the roads connecting 4th node to 15th node are:
# [[4, 11, 9, 15]]
# the roads connecting 6th node to 12th node are:
# [[6, 12]]
# the roads connecting 18th node to 7th node are:
# [[18, 7]]
# the roads connecting 8th node to 9th node are:
# [[8, 11, 9]]
# the roads connecting 8th node to 11th node are:
# [[8, 11]]
# the roads connecting 8th node to 12th node are:
# [[8, 11, 9, 15, 3, 12], [8, 11, 9, 15, 12]]
# the roads connecting 8th node to 15th node are:
# [[8, 11, 9, 15]]
# the roads connecting 11th node to 9th node are:
# [[11, 9]]
# the roads connecting 9th node to 12th node are:
# [[9, 15, 3, 12], [9, 15, 12]]
# the roads connecting 14th node to 9th node are:
# [[14, 9]]
# the roads connecting 9th node to 15th node are:
# [[9, 15]]
# the roads connecting 16th node to 9th node are:
# [[16, 9]]
# the roads connecting 17th node to 9th node are:
# [[17, 11, 9]]
# the roads connecting 11th node to 12th node are:
# [[11, 9, 15, 3, 12], [11, 9, 15, 12]]
# the roads connecting 11th node to 15th node are:
# [[11, 9, 15]]
# the roads connecting 17th node to 11th node are:
# [[17, 11]]
# the roads connecting 14th node to 12th node are:
# [[14, 9, 15, 3, 12], [14, 9, 15, 12], [14, 12]]
# the roads connecting 15th node to 12th node are:
# [[15, 3, 12], [15, 12]]
# the roads connecting 16th node to 12th node are:
# [[16, 3, 12], [16, 9, 15, 3, 12], [16, 9, 15, 12], [16, 12]]
# the roads connecting 17th node to 12th node are:
# [[17, 11, 9, 15, 3, 12], [17, 11, 9, 15, 12]]
# the roads connecting 19th node to 12th node are:
# [[19, 12]]
# the roads connecting 17th node to 13th node are:
# [[17, 13]]
# the roads connecting 14th node to 15th node are:
# [[14, 9, 15]]
# the roads connecting 16th node to 15th node are:
# [[16, 9, 15]]
# the roads connecting 17th node to 15th node are:
# [[17, 11, 9, 15]]
# Rsquare score with all features: 0.667665968383416
# Rsquare Score with selected features: 0.34635970109108205
# n_features= 2
# target= 2
# selected= [5, 17]
# Rsquare score with all features: 0.8340858170084281
# Rsquare Score with selected features: 0.7651641164825633
# n_features= 3
# target= 3
# selected= [6, 12, 14]
# Rsquare score with all features: 0.9500098113882339
# Rsquare Score with selected features: 0.8368890116622084
# n_features= 5
# target= 9
# selected= [4, 14, 15, 16, 17]
# Rsquare score with all features: 0.9201303551029238
# Rsquare Score with selected features: 0.7647526061693217
# n_features= 4
# target= 11
# selected= [4, 8, 14, 17]
# Rsquare score with all features: 0.9278185257694285
# Rsquare Score with selected features: 0.8960510383527307
# n_features= 6
# target= 12
# selected= [3, 6, 9, 14, 15, 19]
# Rsquare score with all features: 0.7567714486034699
# Rsquare Score with selected features: 0.3073805569577428
# n_features= 2
# target= 14
# selected= [9, 16]
# Rsquare score with all features: 0.9377701796431028
# Rsquare Score with selected features: 0.8033667733771294
# n_features= 3
# target= 15
# selected= [9, 16, 19]
# Rsquare score with all features: 0.8035690555796695
# Rsquare Score with selected features: 0.340107129439452
# n_features= 3
# target= 16
# selected= [9, 14, 15]
# Rsquare score with all features: 0.8129562075634944
# Rsquare Score with selected features: 0.32891553939973617
# n_features= 2
# target= 17
# selected= [4, 11]
# Rsquare score with all features: 0.7536526150936038
# Rsquare Score with selected features: 0.7532053078861687
# n_features= 2
# target= 18
# selected= [1, 7]
# Rsquare score with all features: 0.667665968383416
# Rsquare Score with selected features: 0.34732139547531005
# n_features= 3
# target= 2
# selected= [4, 5, 17]
# Rsquare score with all features: 0.9500098113882339
# Rsquare Score with selected features: 0.8368890116622084
# n_features= 5
# target= 9
# selected= [4, 14, 15, 16, 17]
# Rsquare score with all features: 0.9201303551029238
# Rsquare Score with selected features: 0.5127159827672865
# n_features= 2
# target= 11
# selected= [8, 17]
# Rsquare score with all features: 0.9278185257694285
# Rsquare Score with selected features: 0.5497360793042521
# n_features= 3
# target= 12
# selected= [6, 9, 15]
# Rsquare score with all features: 0.7567714486034699
# Rsquare Score with selected features: 0.3073805569577428
# n_features= 2
# target= 14
# selected= [9, 16]
# Rsquare score with all features: 0.9377701796431028
# Rsquare Score with selected features: 0.9054023370545287
# n_features= 4
# target= 15
# selected= [9, 12, 16, 19]
# Rsquare score with all features: 0.8035690555796695
# Rsquare Score with selected features: 0.340107129439452
# n_features= 3
# target= 16
# selected= [9, 14, 15]
# Rsquare score with all features: 0.667665968383416
# Rsquare Score with selected features: 0.34732139547531005
# n_features= 3
# target= 2
# selected= [4, 5, 17]
# Rsquare score with all features: 0.8340858170084281
# Rsquare Score with selected features: 0.7651641164825633
# n_features= 3
# target= 3
# selected= [6, 12, 14]
# Rsquare score with all features: 0.7641314107162925
# Rsquare Score with selected features: 0.0
# n_features= 2
# target= 4
# selected= [8, 17]
# Rsquare score with all features: 0.7704891291715443
# Rsquare Score with selected features: 0.34480662526698846
# n_features= 2
# target= 8
# selected= [4, 11]
# Rsquare score with all features: 0.9201303551029238
# Rsquare Score with selected features: 0.5127159827672865
# n_features= 2
# target= 11
# selected= [8, 17]
# Rsquare score with all features: 0.9278185257694285
# Rsquare Score with selected features: 0.5586841347565064
# n_features= 4
# target= 12
# selected= [6, 9, 14, 15]
# Rsquare score with all features: 0.7567714486034699
# Rsquare Score with selected features: 0.3073805569577428
# n_features= 2
# target= 14
# selected= [9, 16]
# Rsquare score with all features: 0.9377701796431028
# Rsquare Score with selected features: 0.8033667733771294
# n_features= 3
# target= 15
# selected= [9, 16, 19]
# Rsquare score with all features: 0.8035690555796695
# Rsquare Score with selected features: 0.3408760260487582
# n_features= 2
# target= 16
# selected= [9, 14]
# Rsquare score with all features: 0.8129562075634944
# Rsquare Score with selected features: 0.32891553939973617
# n_features= 2
# target= 17
# selected= [4, 11]
# ccccccccccc= 1
# 20  node 20  edges
# children_dic:
# {'0': [1, 12, 16], '1': [2, 15], '2': [], '3': [], '4': [5], '5': [], '6': [13], '7': [9, 15], '8': [12], '9': [16], '10': [], '11': [5], '12': [2, 14], '13': [5], '14': [], '15': [16], '16': [], '17': [], '18': [6, 14], '19': [2, 14]}
# parents_dic:
# {'0': [], '1': [0], '2': [1, 12, 19], '3': [], '4': [], '5': [4, 11, 13], '6': [18], '7': [], '8': [], '9': [7], '10': [], '11': [], '12': [0, 8], '13': [6], '14': [12, 18, 19], '15': [1, 7], '16': [0, 9, 15], '17': [], '18': [], '19': []}
# topological order of the nodes:
# [2, 16, 15, 1, 14, 12, 0, 3, 5, 4, 13, 6, 9, 7, 8, 10, 11, 17, 18, 19]
# the roads connecting 0th node to 1th node are:
# [[0, 1]]
# the roads connecting 0th node to 2th node are:
# [[0, 1, 2], [0, 12, 2]]
# the roads connecting 0th node to 12th node are:
# [[0, 12]]
# the roads connecting 0th node to 14th node are:
# [[0, 12, 14]]
# the roads connecting 0th node to 15th node are:
# [[0, 1, 15]]
# the roads connecting 0th node to 16th node are:
# [[0, 1, 15, 16], [0, 16]]
# the roads connecting 1th node to 2th node are:
# [[1, 2]]
# the roads connecting 1th node to 15th node are:
# [[1, 15]]
# the roads connecting 1th node to 16th node are:
# [[1, 15, 16]]
# the roads connecting 8th node to 2th node are:
# [[8, 12, 2]]
# the roads connecting 12th node to 2th node are:
# [[12, 2]]
# the roads connecting 19th node to 2th node are:
# [[19, 2]]
# the roads connecting 4th node to 5th node are:
# [[4, 5]]
# the roads connecting 6th node to 5th node are:
# [[6, 13, 5]]
# the roads connecting 11th node to 5th node are:
# [[11, 5]]
# the roads connecting 13th node to 5th node are:
# [[13, 5]]
# the roads connecting 18th node to 5th node are:
# [[18, 6, 13, 5]]
# the roads connecting 6th node to 13th node are:
# [[6, 13]]
# the roads connecting 18th node to 6th node are:
# [[18, 6]]
# the roads connecting 7th node to 9th node are:
# [[7, 9]]
# the roads connecting 7th node to 15th node are:
# [[7, 15]]
# the roads connecting 7th node to 16th node are:
# [[7, 9, 16], [7, 15, 16]]
# the roads connecting 8th node to 12th node are:
# [[8, 12]]
# the roads connecting 8th node to 14th node are:
# [[8, 12, 14]]
# the roads connecting 9th node to 16th node are:
# [[9, 16]]
# the roads connecting 12th node to 14th node are:
# [[12, 14]]
# the roads connecting 18th node to 13th node are:
# [[18, 6, 13]]
# the roads connecting 18th node to 14th node are:
# [[18, 14]]
# the roads connecting 19th node to 14th node are:
# [[19, 14]]
# the roads connecting 15th node to 16th node are:
# [[15, 16]]
# Rsquare score with all features: 0.7965429358495789
# Rsquare Score with selected features: 0.6701870772578833
# n_features= 3
# target= 0
# selected= [1, 8, 12]
# Rsquare score with all features: 0.837984637359457
# Rsquare Score with selected features: 0.7554134101130171
# n_features= 3
# target= 1
# selected= [0, 7, 15]
# Rsquare score with all features: 0.8005676283338206
# Rsquare Score with selected features: 0.5793758583302604
# n_features= 3
# target= 2
# selected= [1, 8, 19]
# Rsquare score with all features: 0.7649596782484254
# Rsquare Score with selected features: 0.5425335274028817
# n_features= 3
# target= 5
# selected= [6, 11, 13]
# Rsquare score with all features: 0.8555437319772532
# Rsquare Score with selected features: 0.6952167883818359
# n_features= 2
# target= 6
# selected= [11, 13]
# Rsquare score with all features: 0.6792423547976327
# Rsquare Score with selected features: 0.5100249359216049
# n_features= 2
# target= 7
# selected= [1, 15]
# Rsquare score with all features: 0.7514323253896018
# Rsquare Score with selected features: 0.4957963003141873
# n_features= 2
# target= 9
# selected= [0, 7]
# Rsquare score with all features: 0.8885214547779027
# Rsquare Score with selected features: 0.6680678396786209
# n_features= 4
# target= 12
# selected= [0, 8, 18, 19]
# Rsquare score with all features: 0.8506531913736063
# Rsquare Score with selected features: 0.7699321016409275
# n_features= 2
# target= 13
# selected= [5, 6]
# Rsquare score with all features: 0.8138757222634712
# Rsquare Score with selected features: 0.8126271935436445
# n_features= 3
# target= 14
# selected= [12, 18, 19]
# Rsquare score with all features: 0.859097275574374
# Rsquare Score with selected features: 0.7980970813090974
# n_features= 3
# target= 15
# selected= [1, 7, 16]
# Rsquare score with all features: 0.9056218043854499
# Rsquare Score with selected features: 0.9058096552661692
# n_features= 3
# target= 16
# selected= [0, 9, 15]
# Rsquare score with all features: 0.6704284383812616
# Rsquare Score with selected features: 0.510984365489168
# n_features= 2
# target= 18
# selected= [6, 12]
# Rsquare score with all features: 0.6463261915494429
# Rsquare Score with selected features: 0.0
# n_features= 2
# target= 19
# selected= [8, 12]
# Rsquare score with all features: 0.7965429358495789
# Rsquare Score with selected features: 0.6701870772578833
# n_features= 3
# target= 0
# selected= [1, 8, 12]
# Rsquare score with all features: 0.8005676283338206
# Rsquare Score with selected features: 0.3924133250641437
# n_features= 2
# target= 2
# selected= [1, 8]
# Rsquare score with all features: 0.6643826768925138
# Rsquare Score with selected features: 0.4761874308059788
# n_features= 2
# target= 8
# selected= [0, 12]
# Rsquare score with all features: 0.8138757222634712
# Rsquare Score with selected features: 0.6554505462754125
# n_features= 2
# target= 14
# selected= [12, 18]
# Rsquare score with all features: 0.9056218043854499
# Rsquare Score with selected features: 0.838337984976532
# n_features= 2
# target= 16
# selected= [9, 15]
# ccccccccccc= 2
# 20  node 20  edges
# children_dic:
# {'0': [17], '1': [], '2': [4, 5], '3': [5], '4': [], '5': [12, 17], '6': [11], '7': [14, 16], '8': [0, 17], '9': [], '10': [4], '11': [0, 1, 8, 17], '12': [1], '13': [], '14': [9], '15': [], '16': [], '17': [], '18': [], '19': [1, 17]}
# parents_dic:
# {'0': [8, 11], '1': [11, 12, 19], '2': [], '3': [], '4': [2, 10], '5': [2, 3], '6': [], '7': [], '8': [11], '9': [14], '10': [], '11': [6], '12': [5], '13': [], '14': [7], '15': [], '16': [7], '17': [0, 5, 8, 11, 19], '18': [], '19': []}
# topological order of the nodes:
# [17, 0, 1, 4, 12, 5, 2, 3, 8, 11, 6, 9, 14, 16, 7, 10, 13, 15, 18, 19]
# the roads connecting 6th node to 0th node are:
# [[6, 11, 0], [6, 11, 8, 0]]
# the roads connecting 8th node to 0th node are:
# [[8, 0]]
# the roads connecting 11th node to 0th node are:
# [[11, 0], [11, 8, 0]]
# the roads connecting 0th node to 17th node are:
# [[0, 17]]
# the roads connecting 2th node to 1th node are:
# [[2, 5, 12, 1]]
# the roads connecting 3th node to 1th node are:
# [[3, 5, 12, 1]]
# the roads connecting 5th node to 1th node are:
# [[5, 12, 1]]
# the roads connecting 6th node to 1th node are:
# [[6, 11, 1]]
# the roads connecting 11th node to 1th node are:
# [[11, 1]]
# the roads connecting 12th node to 1th node are:
# [[12, 1]]
# the roads connecting 19th node to 1th node are:
# [[19, 1]]
# the roads connecting 2th node to 4th node are:
# [[2, 4]]
# the roads connecting 2th node to 5th node are:
# [[2, 5]]
# the roads connecting 2th node to 12th node are:
# [[2, 5, 12]]
# the roads connecting 2th node to 17th node are:
# [[2, 5, 17]]
# the roads connecting 3th node to 5th node are:
# [[3, 5]]
# the roads connecting 3th node to 12th node are:
# [[3, 5, 12]]
# the roads connecting 3th node to 17th node are:
# [[3, 5, 17]]
# the roads connecting 10th node to 4th node are:
# [[10, 4]]
# the roads connecting 5th node to 12th node are:
# [[5, 12]]
# the roads connecting 5th node to 17th node are:
# [[5, 17]]
# the roads connecting 6th node to 8th node are:
# [[6, 11, 8]]
# the roads connecting 6th node to 11th node are:
# [[6, 11]]
# the roads connecting 6th node to 17th node are:
# [[6, 11, 0, 17], [6, 11, 8, 0, 17], [6, 11, 8, 17], [6, 11, 17]]
# the roads connecting 7th node to 9th node are:
# [[7, 14, 9]]
# the roads connecting 7th node to 14th node are:
# [[7, 14]]
# the roads connecting 7th node to 16th node are:
# [[7, 16]]
# the roads connecting 11th node to 8th node are:
# [[11, 8]]
# the roads connecting 8th node to 17th node are:
# [[8, 0, 17], [8, 17]]
# the roads connecting 14th node to 9th node are:
# [[14, 9]]
# the roads connecting 11th node to 17th node are:
# [[11, 0, 17], [11, 8, 0, 17], [11, 8, 17], [11, 17]]
# the roads connecting 19th node to 17th node are:
# [[19, 17]]
# Rsquare score with all features: 0.8299347164882446
# Rsquare Score with selected features: 0.7556606234991441
# n_features= 3
# target= 0
# selected= [5, 17, 19]
# Rsquare score with all features: 0.7513342167446966
# Rsquare Score with selected features: 0.505230199061018
# n_features= 3
# target= 1
# selected= [5, 12, 19]
# Rsquare score with all features: 0.6438438959968381
# Rsquare Score with selected features: 0.49491661943361276
# n_features= 2
# target= 2
# selected= [4, 10]
# Rsquare score with all features: 0.6492437657284744
# Rsquare Score with selected features: 0.6482612932072848
# n_features= 2
# target= 4
# selected= [2, 10]
# Rsquare score with all features: 0.9089989989336688
# Rsquare Score with selected features: 0.8252711203656039
# n_features= 4
# target= 5
# selected= [0, 1, 2, 12]
# Rsquare score with all features: 0.75269377968349
# Rsquare Score with selected features: 0.6719445527717793
# n_features= 2
# target= 7
# selected= [9, 14]
# Rsquare score with all features: 0.8233526955683137
# Rsquare Score with selected features: 0.695233781544901
# n_features= 3
# target= 8
# selected= [6, 17, 19]
# Rsquare score with all features: 0.8626121350330074
# Rsquare Score with selected features: 0.7862176216658363
# n_features= 5
# target= 11
# selected= [0, 1, 6, 17, 19]
# Rsquare score with all features: 0.8701298258319018
# Rsquare Score with selected features: 0.8060547178496767
# n_features= 2
# target= 12
# selected= [1, 5]
# Rsquare score with all features: 0.7605118053652143
# Rsquare Score with selected features: 0.7589928744320528
# n_features= 2
# target= 14
# selected= [7, 9]
# Rsquare score with all features: 0.9478094655159427
# Rsquare Score with selected features: 0.9477389382359583
# n_features= 5
# target= 17
# selected= [0, 5, 8, 11, 19]
# Rsquare score with all features: 0.672722195830671
# Rsquare Score with selected features: 0.0008499490765107032
# n_features= 2
# target= 19
# selected= [0, 11]
# Rsquare score with all features: 0.8299347164882446
# Rsquare Score with selected features: 0.6489731832517042
# n_features= 2
# target= 0
# selected= [17, 19]
# Rsquare score with all features: 0.7513342167446966
# Rsquare Score with selected features: 0.35275566107634226
# n_features= 2
# target= 1
# selected= [12, 19]
# Rsquare score with all features: 0.6438438959968381
# Rsquare Score with selected features: 0.49491661943361276
# n_features= 2
# target= 2
# selected= [4, 10]
# Rsquare score with all features: 0.4637067694631095
# Rsquare Score with selected features: 0.4622541415807814
# n_features= 2
# target= 3
# selected= [2, 5]
# Rsquare score with all features: 0.7264716951464474
# Rsquare Score with selected features: 0.6900326342254504
# n_features= 4
# target= 6
# selected= [1, 8, 11, 19]
# Rsquare score with all features: 0.8233526955683137
# Rsquare Score with selected features: 0.6666606663081912
# n_features= 2
# target= 8
# selected= [6, 17]
# Rsquare score with all features: 0.8626121350330074
# Rsquare Score with selected features: 0.45797369965074675
# n_features= 2
# target= 11
# selected= [6, 19]
# Rsquare score with all features: 0.8701298258319018
# Rsquare Score with selected features: 0.8060547178496767
# n_features= 2
# target= 12
# selected= [1, 5]
# Rsquare score with all features: 0.9478094655159427
# Rsquare Score with selected features: 0.9477389382359583
# n_features= 5
# target= 17
# selected= [0, 5, 8, 11, 19]
# Rsquare score with all features: 0.7513342167446966
# Rsquare Score with selected features: 0.35275566107634226
# n_features= 2
# target= 1
# selected= [12, 19]
# Rsquare score with all features: 0.7264716951464474
# Rsquare Score with selected features: 0.6395590566026244
# n_features= 2
# target= 6
# selected= [8, 11]
# Rsquare score with all features: 0.9478094655159427
# Rsquare Score with selected features: 0.7326849014094428
# n_features= 2
# target= 17
# selected= [0, 11]
# ccccccccccc= 3
# 20  node 20  edges
# children_dic:
# {'0': [3], '1': [4], '2': [], '3': [], '4': [], '5': [6], '6': [], '7': [], '8': [7], '9': [], '10': [4, 6, 16, 17], '11': [1, 15, 16], '12': [16], '13': [10, 15], '14': [17], '15': [0, 6], '16': [14], '17': [3], '18': [], '19': [0]}
# parents_dic:
# {'0': [15, 19], '1': [11], '2': [], '3': [0, 17], '4': [1, 10], '5': [], '6': [5, 10, 15], '7': [8], '8': [], '9': [], '10': [13], '11': [], '12': [], '13': [], '14': [16], '15': [11, 13], '16': [10, 11, 12], '17': [10, 14], '18': [], '19': []}
# topological order of the nodes:
# [3, 0, 4, 1, 2, 6, 5, 7, 8, 9, 17, 14, 16, 10, 15, 11, 12, 13, 18, 19]
# the roads connecting 0th node to 3th node are:
# [[0, 3]]
# the roads connecting 11th node to 0th node are:
# [[11, 15, 0]]
# the roads connecting 13th node to 0th node are:
# [[13, 15, 0]]
# the roads connecting 15th node to 0th node are:
# [[15, 0]]
# the roads connecting 19th node to 0th node are:
# [[19, 0]]
# the roads connecting 1th node to 4th node are:
# [[1, 4]]
# the roads connecting 11th node to 1th node are:
# [[11, 1]]
# the roads connecting 10th node to 3th node are:
# [[10, 16, 14, 17, 3], [10, 17, 3]]
# the roads connecting 11th node to 3th node are:
# [[11, 15, 0, 3], [11, 16, 14, 17, 3]]
# the roads connecting 12th node to 3th node are:
# [[12, 16, 14, 17, 3]]
# the roads connecting 13th node to 3th node are:
# [[13, 10, 16, 14, 17, 3], [13, 10, 17, 3], [13, 15, 0, 3]]
# the roads connecting 14th node to 3th node are:
# [[14, 17, 3]]
# the roads connecting 15th node to 3th node are:
# [[15, 0, 3]]
# the roads connecting 16th node to 3th node are:
# [[16, 14, 17, 3]]
# the roads connecting 17th node to 3th node are:
# [[17, 3]]
# the roads connecting 19th node to 3th node are:
# [[19, 0, 3]]
# the roads connecting 10th node to 4th node are:
# [[10, 4]]
# the roads connecting 11th node to 4th node are:
# [[11, 1, 4]]
# the roads connecting 13th node to 4th node are:
# [[13, 10, 4]]
# the roads connecting 5th node to 6th node are:
# [[5, 6]]
# the roads connecting 10th node to 6th node are:
# [[10, 6]]
# the roads connecting 11th node to 6th node are:
# [[11, 15, 6]]
# the roads connecting 13th node to 6th node are:
# [[13, 10, 6], [13, 15, 6]]
# the roads connecting 15th node to 6th node are:
# [[15, 6]]
# the roads connecting 8th node to 7th node are:
# [[8, 7]]
# the roads connecting 13th node to 10th node are:
# [[13, 10]]
# the roads connecting 10th node to 14th node are:
# [[10, 16, 14]]
# the roads connecting 10th node to 16th node are:
# [[10, 16]]
# the roads connecting 10th node to 17th node are:
# [[10, 16, 14, 17], [10, 17]]
# the roads connecting 11th node to 14th node are:
# [[11, 16, 14]]
# the roads connecting 11th node to 15th node are:
# [[11, 15]]
# the roads connecting 11th node to 16th node are:
# [[11, 16]]
# the roads connecting 11th node to 17th node are:
# [[11, 16, 14, 17]]
# the roads connecting 12th node to 14th node are:
# [[12, 16, 14]]
# the roads connecting 12th node to 16th node are:
# [[12, 16]]
# the roads connecting 12th node to 17th node are:
# [[12, 16, 14, 17]]
# the roads connecting 13th node to 14th node are:
# [[13, 10, 16, 14]]
# the roads connecting 13th node to 15th node are:
# [[13, 15]]
# the roads connecting 13th node to 16th node are:
# [[13, 10, 16]]
# the roads connecting 13th node to 17th node are:
# [[13, 10, 16, 14, 17], [13, 10, 17]]
# the roads connecting 16th node to 14th node are:
# [[16, 14]]
# the roads connecting 14th node to 17th node are:
# [[14, 17]]
# the roads connecting 16th node to 17th node are:
# [[16, 14, 17]]
# Rsquare score with all features: 0.830476819486692
# Rsquare Score with selected features: 0.002115118850872122
# n_features= 3
# target= 0
# selected= [11, 14, 17]
# Rsquare score with all features: 0.7457638268353584
# Rsquare Score with selected features: 0.5599295365607263
# n_features= 2
# target= 1
# selected= [4, 10]
# Rsquare score with all features: 0.7985105093019376
# Rsquare Score with selected features: 0.5963910576743148
# n_features= 2
# target= 3
# selected= [0, 14]
# Rsquare score with all features: 0.7475047726986239
# Rsquare Score with selected features: 0.24930456816640356
# n_features= 2
# target= 4
# selected= [10, 13]
# Rsquare score with all features: 0.7637396213920021
# Rsquare Score with selected features: 0.4931273582521347
# n_features= 3
# target= 6
# selected= [5, 10, 13]
# Rsquare score with all features: 0.9265394635791363
# Rsquare Score with selected features: 0.8012945639790116
# n_features= 5
# target= 10
# selected= [12, 13, 14, 16, 17]
# Rsquare score with all features: 0.8632787569593241
# Rsquare Score with selected features: 0.5094188848231174
# n_features= 3
# target= 11
# selected= [12, 13, 15]
# Rsquare score with all features: 0.8944698383683677
# Rsquare Score with selected features: 0.5886773952491515
# n_features= 2
# target= 13
# selected= [10, 15]
# Rsquare score with all features: 0.8254212575003722
# Rsquare Score with selected features: 0.6402739282024423
# n_features= 2
# target= 14
# selected= [10, 17]
# Rsquare score with all features: 0.8970647354998805
# Rsquare Score with selected features: 0.7617251416467732
# n_features= 4
# target= 15
# selected= [6, 11, 13, 19]
# Rsquare score with all features: 0.8991807338362132
# Rsquare Score with selected features: 0.8981444998923072
# n_features= 4
# target= 16
# selected= [10, 11, 12, 14]
# Rsquare score with all features: 0.8858787937917074
# Rsquare Score with selected features: 0.7737846479610644
# n_features= 3
# target= 17
# selected= [0, 10, 14]
# Rsquare score with all features: 0.830476819486692
# Rsquare Score with selected features: 0.0
# n_features= 2
# target= 0
# selected= [11, 14]
# Rsquare score with all features: 0.7985105093019376
# Rsquare Score with selected features: 0.7954682427589423
# n_features= 4
# target= 3
# selected= [0, 10, 14, 17]
# Rsquare score with all features: 0.7475047726986239
# Rsquare Score with selected features: 0.24930456816640356
# n_features= 2
# target= 4
# selected= [10, 13]
# Rsquare score with all features: 0.7637396213920021
# Rsquare Score with selected features: 0.21097178379993775
# n_features= 2
# target= 6
# selected= [10, 13]
# Rsquare score with all features: 0.9265394635791363
# Rsquare Score with selected features: 0.4975492790924161
# n_features= 2
# target= 10
# selected= [13, 14]
# Rsquare score with all features: 0.8632787569593241
# Rsquare Score with selected features: 0.6262410648970023
# n_features= 4
# target= 11
# selected= [12, 13, 15, 16]
# Rsquare score with all features: 0.8944698383683677
# Rsquare Score with selected features: 0.8594013867711157
# n_features= 5
# target= 13
# selected= [5, 6, 10, 11, 15]
# Rsquare score with all features: 0.8254212575003722
# Rsquare Score with selected features: 0.7850540279946947
# n_features= 4
# target= 14
# selected= [0, 3, 10, 17]
# Rsquare score with all features: 0.8991807338362132
# Rsquare Score with selected features: 0.4330085921869956
# n_features= 2
# target= 16
# selected= [11, 12]
# Rsquare score with all features: 0.8858787937917074
# Rsquare Score with selected features: 0.773374818408805
# n_features= 2
# target= 17
# selected= [10, 14]
# Rsquare score with all features: 0.7985105093019376
# Rsquare Score with selected features: 0.5981801799457398
# n_features= 3
# target= 3
# selected= [0, 10, 14]
# Rsquare score with all features: 0.8632787569593241
# Rsquare Score with selected features: 0.5097439133124825
# n_features= 2
# target= 11
# selected= [13, 15]
# Rsquare score with all features: 0.8944698383683677
# Rsquare Score with selected features: 0.5886773952491515
# n_features= 2
# target= 13
# selected= [10, 15]
# Rsquare score with all features: 0.8858787937917074
# Rsquare Score with selected features: 0.7737846479610644
# n_features= 3
# target= 17
# selected= [0, 10, 14]
# ccccccccccc= 4
# 20  node 20  edges
# children_dic:
# {'0': [4, 10], '1': [4, 10], '2': [], '3': [], '4': [], '5': [4], '6': [4], '7': [6], '8': [6], '9': [12], '10': [5], '11': [1, 5, 6], '12': [16, 18], '13': [], '14': [17], '15': [], '16': [1, 4, 5], '17': [], '18': [], '19': [4]}
# parents_dic:
# {'0': [], '1': [11, 16], '2': [], '3': [], '4': [0, 1, 5, 6, 16, 19], '5': [10, 11, 16], '6': [7, 8, 11], '7': [], '8': [], '9': [], '10': [0, 1], '11': [], '12': [9], '13': [], '14': [], '15': [], '16': [12], '17': [14], '18': [12], '19': []}
# topological order of the nodes:
# [4, 5, 10, 0, 1, 2, 3, 6, 7, 8, 16, 18, 12, 9, 11, 13, 17, 14, 15, 19]
# the roads connecting 0th node to 4th node are:
# [[0, 4], [0, 10, 5, 4]]
# the roads connecting 0th node to 5th node are:
# [[0, 10, 5]]
# the roads connecting 0th node to 10th node are:
# [[0, 10]]
# the roads connecting 1th node to 4th node are:
# [[1, 4], [1, 10, 5, 4]]
# the roads connecting 1th node to 5th node are:
# [[1, 10, 5]]
# the roads connecting 9th node to 1th node are:
# [[9, 12, 16, 1]]
# the roads connecting 1th node to 10th node are:
# [[1, 10]]
# the roads connecting 11th node to 1th node are:
# [[11, 1]]
# the roads connecting 12th node to 1th node are:
# [[12, 16, 1]]
# the roads connecting 16th node to 1th node are:
# [[16, 1]]
# the roads connecting 5th node to 4th node are:
# [[5, 4]]
# the roads connecting 6th node to 4th node are:
# [[6, 4]]
# the roads connecting 7th node to 4th node are:
# [[7, 6, 4]]
# the roads connecting 8th node to 4th node are:
# [[8, 6, 4]]
# the roads connecting 9th node to 4th node are:
# [[9, 12, 16, 1, 4], [9, 12, 16, 1, 10, 5, 4], [9, 12, 16, 4], [9, 12, 16, 5, 4]]
# the roads connecting 10th node to 4th node are:
# [[10, 5, 4]]
# the roads connecting 11th node to 4th node are:
# [[11, 1, 4], [11, 1, 10, 5, 4], [11, 5, 4], [11, 6, 4]]
# the roads connecting 12th node to 4th node are:
# [[12, 16, 1, 4], [12, 16, 1, 10, 5, 4], [12, 16, 4], [12, 16, 5, 4]]
# the roads connecting 16th node to 4th node are:
# [[16, 1, 4], [16, 1, 10, 5, 4], [16, 4], [16, 5, 4]]
# the roads connecting 19th node to 4th node are:
# [[19, 4]]
# the roads connecting 9th node to 5th node are:
# [[9, 12, 16, 1, 10, 5], [9, 12, 16, 5]]
# the roads connecting 10th node to 5th node are:
# [[10, 5]]
# the roads connecting 11th node to 5th node are:
# [[11, 1, 10, 5], [11, 5]]
# the roads connecting 12th node to 5th node are:
# [[12, 16, 1, 10, 5], [12, 16, 5]]
# the roads connecting 16th node to 5th node are:
# [[16, 1, 10, 5], [16, 5]]
# the roads connecting 7th node to 6th node are:
# [[7, 6]]
# the roads connecting 8th node to 6th node are:
# [[8, 6]]
# the roads connecting 11th node to 6th node are:
# [[11, 6]]
# the roads connecting 9th node to 10th node are:
# [[9, 12, 16, 1, 10]]
# the roads connecting 9th node to 12th node are:
# [[9, 12]]
# the roads connecting 9th node to 16th node are:
# [[9, 12, 16]]
# the roads connecting 9th node to 18th node are:
# [[9, 12, 18]]
# the roads connecting 11th node to 10th node are:
# [[11, 1, 10]]
# the roads connecting 12th node to 10th node are:
# [[12, 16, 1, 10]]
# the roads connecting 16th node to 10th node are:
# [[16, 1, 10]]
# the roads connecting 12th node to 16th node are:
# [[12, 16]]
# the roads connecting 12th node to 18th node are:
# [[12, 18]]
# the roads connecting 14th node to 17th node are:
# [[14, 17]]
# Rsquare score with all features: 0.8482145792048578
# Rsquare Score with selected features: 0.004399763191302197
# n_features= 2
# target= 0
# selected= [1, 11]
# Rsquare score with all features: 0.9476745898610915
# Rsquare Score with selected features: 0.7908437371420991
# n_features= 4
# target= 1
# selected= [0, 5, 10, 11]
# Rsquare score with all features: 0.9029153533448284
# Rsquare Score with selected features: 0.6733501080892312
# n_features= 6
# target= 4
# selected= [0, 1, 6, 7, 8, 11]
# Rsquare score with all features: 0.8703120491740239
# Rsquare Score with selected features: 0.6248181788921479
# n_features= 4
# target= 5
# selected= [0, 1, 10, 11]
# Rsquare score with all features: 0.8787878421963522
# Rsquare Score with selected features: 0.7563548087307288
# n_features= 4
# target= 6
# selected= [0, 7, 8, 11]
# Rsquare score with all features: 0.9218002158848092
# Rsquare Score with selected features: 0.774286444291161
# n_features= 3
# target= 10
# selected= [0, 1, 11]
# Rsquare score with all features: 0.8721777984434309
# Rsquare Score with selected features: 0.34268633524484937
# n_features= 3
# target= 11
# selected= [0, 1, 7]
# Rsquare score with all features: 0.899058419746937
# Rsquare Score with selected features: 0.7981368738573503
# n_features= 3
# target= 12
# selected= [1, 11, 16]
# Rsquare score with all features: 0.8796653776293698
# Rsquare Score with selected features: 0.8565219426558046
# n_features= 4
# target= 16
# selected= [1, 5, 11, 12]
# Rsquare score with all features: 0.9476745898610915
# Rsquare Score with selected features: 0.34402072810997
# n_features= 2
# target= 1
# selected= [0, 11]
# Rsquare score with all features: 0.9029153533448284
# Rsquare Score with selected features: 0.6733501080892312
# n_features= 6
# target= 4
# selected= [0, 1, 6, 7, 8, 11]
# Rsquare score with all features: 0.8703120491740239
# Rsquare Score with selected features: 0.3766440058327667
# n_features= 3
# target= 5
# selected= [0, 1, 11]
# Rsquare score with all features: 0.5015981357121575
# Rsquare Score with selected features: 0.5024908660666116
# n_features= 2
# target= 9
# selected= [11, 12]
# Rsquare score with all features: 0.9218002158848092
# Rsquare Score with selected features: 0.774286444291161
# n_features= 3
# target= 10
# selected= [0, 1, 11]
# Rsquare score with all features: 0.8721777984434309
# Rsquare Score with selected features: 0.341833030264746
# n_features= 2
# target= 11
# selected= [0, 1]
# Rsquare score with all features: 0.899058419746937
# Rsquare Score with selected features: 0.7981368738573503
# n_features= 3
# target= 12
# selected= [1, 11, 16]
# Rsquare score with all features: 0.8796653776293698
# Rsquare Score with selected features: 0.8248567911401343
# n_features= 3
# target= 16
# selected= [1, 11, 12]
# Rsquare score with all features: 0.9476745898610915
# Rsquare Score with selected features: 0.34402072810997
# n_features= 2
# target= 1
# selected= [0, 11]
# Rsquare score with all features: 0.9029153533448284
# Rsquare Score with selected features: 0.576038312268701
# n_features= 4
# target= 4
# selected= [0, 1, 7, 11]
# Rsquare score with all features: 0.8703120491740239
# Rsquare Score with selected features: 0.3766440058327667
# n_features= 3
# target= 5
# selected= [0, 1, 11]
# Rsquare score with all features: 0.5015981357121575
# Rsquare Score with selected features: 0.5031367805112833
# n_features= 3
# target= 9
# selected= [6, 11, 12]
# Rsquare score with all features: 0.899058419746937
# Rsquare Score with selected features: 0.7620536948771408
# n_features= 2
# target= 12
# selected= [1, 16]
# ccccccccccc= 5
# 20  node 20  edges
# children_dic:
# {'0': [2, 16], '1': [17], '2': [], '3': [12], '4': [], '5': [16], '6': [19], '7': [0, 12], '8': [], '9': [12], '10': [], '11': [5, 12], '12': [], '13': [2, 7], '14': [12, 16], '15': [], '16': [12], '17': [15], '18': [4, 12], '19': [5]}
# parents_dic:
# {'0': [7], '1': [], '2': [0, 13], '3': [], '4': [18], '5': [11, 19], '6': [], '7': [13], '8': [], '9': [], '10': [], '11': [], '12': [3, 7, 9, 11, 14, 16, 18], '13': [], '14': [], '15': [17], '16': [0, 5, 14], '17': [1], '18': [], '19': [6]}
# topological order of the nodes:
# [2, 12, 16, 0, 15, 17, 1, 3, 4, 5, 19, 6, 7, 8, 9, 10, 11, 13, 14, 18]
# the roads connecting 0th node to 2th node are:
# [[0, 2]]
# the roads connecting 7th node to 0th node are:
# [[7, 0]]
# the roads connecting 0th node to 12th node are:
# [[0, 16, 12]]
# the roads connecting 13th node to 0th node are:
# [[13, 7, 0]]
# the roads connecting 0th node to 16th node are:
# [[0, 16]]
# the roads connecting 1th node to 15th node are:
# [[1, 17, 15]]
# the roads connecting 1th node to 17th node are:
# [[1, 17]]
# the roads connecting 7th node to 2th node are:
# [[7, 0, 2]]
# the roads connecting 13th node to 2th node are:
# [[13, 2], [13, 7, 0, 2]]
# the roads connecting 3th node to 12th node are:
# [[3, 12]]
# the roads connecting 18th node to 4th node are:
# [[18, 4]]
# the roads connecting 6th node to 5th node are:
# [[6, 19, 5]]
# the roads connecting 11th node to 5th node are:
# [[11, 5]]
# the roads connecting 5th node to 12th node are:
# [[5, 16, 12]]
# the roads connecting 5th node to 16th node are:
# [[5, 16]]
# the roads connecting 19th node to 5th node are:
# [[19, 5]]
# the roads connecting 6th node to 12th node are:
# [[6, 19, 5, 16, 12]]
# the roads connecting 6th node to 16th node are:
# [[6, 19, 5, 16]]
# the roads connecting 6th node to 19th node are:
# [[6, 19]]
# the roads connecting 7th node to 12th node are:
# [[7, 0, 16, 12], [7, 12]]
# the roads connecting 13th node to 7th node are:
# [[13, 7]]
# the roads connecting 7th node to 16th node are:
# [[7, 0, 16]]
# the roads connecting 9th node to 12th node are:
# [[9, 12]]
# the roads connecting 11th node to 12th node are:
# [[11, 5, 16, 12], [11, 12]]
# the roads connecting 11th node to 16th node are:
# [[11, 5, 16]]
# the roads connecting 13th node to 12th node are:
# [[13, 7, 0, 16, 12], [13, 7, 12]]
# the roads connecting 14th node to 12th node are:
# [[14, 12], [14, 16, 12]]
# the roads connecting 16th node to 12th node are:
# [[16, 12]]
# the roads connecting 18th node to 12th node are:
# [[18, 12]]
# the roads connecting 19th node to 12th node are:
# [[19, 5, 16, 12]]
# the roads connecting 13th node to 16th node are:
# [[13, 7, 0, 16]]
# the roads connecting 14th node to 16th node are:
# [[14, 16]]
# the roads connecting 17th node to 15th node are:
# [[17, 15]]
# the roads connecting 19th node to 16th node are:
# [[19, 5, 16]]
# Rsquare score with all features: 0.8715106586435176
# Rsquare Score with selected features: 0.5214270598695402
# n_features= 3
# target= 0
# selected= [5, 13, 16]
# Rsquare score with all features: 0.7413208431232545
# Rsquare Score with selected features: 0.7399822218060228
# n_features= 2
# target= 2
# selected= [0, 13]
# Rsquare score with all features: 0.8908329795300879
# Rsquare Score with selected features: 0.6773880736849992
# n_features= 3
# target= 5
# selected= [0, 11, 16]
# Rsquare score with all features: 0.8184173008122013
# Rsquare Score with selected features: 0.7439278836740826
# n_features= 3
# target= 7
# selected= [0, 3, 13]
# Rsquare score with all features: 0.6442845664888753
# Rsquare Score with selected features: 0.3247275902164547
# n_features= 2
# target= 11
# selected= [5, 6]
# Rsquare score with all features: 0.8840848954369653
# Rsquare Score with selected features: 0.7309168168157651
# n_features= 7
# target= 12
# selected= [0, 3, 5, 9, 11, 16, 18]
# Rsquare score with all features: 0.7443212451210497
# Rsquare Score with selected features: 0.6628535708564471
# n_features= 2
# target= 13
# selected= [0, 7]
# Rsquare score with all features: 0.48767620201784156
# Rsquare Score with selected features: 0.23117353656314876
# n_features= 2
# target= 14
# selected= [5, 16]
# Rsquare score with all features: 0.9290085575561731
# Rsquare Score with selected features: 0.8819213118709291
# n_features= 4
# target= 16
# selected= [0, 5, 12, 14]
# Rsquare score with all features: 0.7580553151439311
# Rsquare Score with selected features: 0.754990257743013
# n_features= 2
# target= 17
# selected= [1, 15]
# Rsquare score with all features: 0.6510893344182794
# Rsquare Score with selected features: 0.4866729956122803
# n_features= 2
# target= 18
# selected= [4, 16]
# Rsquare score with all features: 0.7458246966375908
# Rsquare Score with selected features: 0.6581891934857558
# n_features= 2
# target= 19
# selected= [5, 6]
# Rsquare score with all features: 0.8715106586435176
# Rsquare Score with selected features: 0.5216522212552849
# n_features= 2
# target= 0
# selected= [5, 16]
# Rsquare score with all features: 0.8908329795300879
# Rsquare Score with selected features: 0.6132502986138542
# n_features= 2
# target= 5
# selected= [0, 16]
# Rsquare score with all features: 0.8184173008122013
# Rsquare Score with selected features: 0.7435812070392818
# n_features= 2
# target= 7
# selected= [0, 13]
# Rsquare score with all features: 0.8840848954369653
# Rsquare Score with selected features: 0.4990637959438078
# n_features= 4
# target= 12
# selected= [0, 3, 9, 16]
# Rsquare score with all features: 0.7443212451210497
# Rsquare Score with selected features: 0.6628535708564471
# n_features= 2
# target= 13
# selected= [0, 7]
# Rsquare score with all features: 0.9290085575561731
# Rsquare Score with selected features: 0.8585332957264111
# n_features= 3
# target= 16
# selected= [0, 5, 14]
# Rsquare score with all features: 0.8840848954369653
# Rsquare Score with selected features: 0.4983079769044752
# n_features= 3
# target= 12
# selected= [3, 9, 16]
# Rsquare score with all features: 0.7443212451210497
# Rsquare Score with selected features: 0.6628535708564471
# n_features= 2
# target= 13
# selected= [0, 7]
# Rsquare score with all features: 0.9290085575561731
# Rsquare Score with selected features: 0.726595915835158
# n_features= 2
# target= 16
# selected= [0, 5]
# ccccccccccc= 6
# 20  node 20  edges
# children_dic:
# {'0': [15], '1': [], '2': [], '3': [17, 19], '4': [], '5': [], '6': [15], '7': [5], '8': [], '9': [8, 10], '10': [5, 18], '11': [2, 15], '12': [0, 15], '13': [5, 14], '14': [3], '15': [], '16': [6], '17': [], '18': [0, 6], '19': [15]}
# parents_dic:
# {'0': [12, 18], '1': [], '2': [11], '3': [14], '4': [], '5': [7, 10, 13], '6': [16, 18], '7': [], '8': [9], '9': [], '10': [9], '11': [], '12': [], '13': [], '14': [13], '15': [0, 6, 11, 12, 19], '16': [], '17': [3], '18': [10], '19': [3]}
# topological order of the nodes:
# [15, 0, 1, 2, 17, 19, 3, 4, 5, 6, 7, 8, 18, 10, 9, 11, 12, 14, 13, 16]
# the roads connecting 9th node to 0th node are:
# [[9, 10, 18, 0]]
# the roads connecting 10th node to 0th node are:
# [[10, 18, 0]]
# the roads connecting 12th node to 0th node are:
# [[12, 0]]
# the roads connecting 0th node to 15th node are:
# [[0, 15]]
# the roads connecting 18th node to 0th node are:
# [[18, 0]]
# the roads connecting 11th node to 2th node are:
# [[11, 2]]
# the roads connecting 13th node to 3th node are:
# [[13, 14, 3]]
# the roads connecting 14th node to 3th node are:
# [[14, 3]]
# the roads connecting 3th node to 15th node are:
# [[3, 19, 15]]
# the roads connecting 3th node to 17th node are:
# [[3, 17]]
# the roads connecting 3th node to 19th node are:
# [[3, 19]]
# the roads connecting 7th node to 5th node are:
# [[7, 5]]
# the roads connecting 9th node to 5th node are:
# [[9, 10, 5]]
# the roads connecting 10th node to 5th node are:
# [[10, 5]]
# the roads connecting 13th node to 5th node are:
# [[13, 5]]
# the roads connecting 9th node to 6th node are:
# [[9, 10, 18, 6]]
# the roads connecting 10th node to 6th node are:
# [[10, 18, 6]]
# the roads connecting 6th node to 15th node are:
# [[6, 15]]
# the roads connecting 16th node to 6th node are:
# [[16, 6]]
# the roads connecting 18th node to 6th node are:
# [[18, 6]]
# the roads connecting 9th node to 8th node are:
# [[9, 8]]
# the roads connecting 9th node to 10th node are:
# [[9, 10]]
# the roads connecting 9th node to 15th node are:
# [[9, 10, 18, 0, 15], [9, 10, 18, 6, 15]]
# the roads connecting 9th node to 18th node are:
# [[9, 10, 18]]
# the roads connecting 10th node to 15th node are:
# [[10, 18, 0, 15], [10, 18, 6, 15]]
# the roads connecting 10th node to 18th node are:
# [[10, 18]]
# the roads connecting 11th node to 15th node are:
# [[11, 15]]
# the roads connecting 12th node to 15th node are:
# [[12, 0, 15], [12, 15]]
# the roads connecting 13th node to 14th node are:
# [[13, 14]]
# the roads connecting 13th node to 15th node are:
# [[13, 14, 3, 19, 15]]
# the roads connecting 13th node to 17th node are:
# [[13, 14, 3, 17]]
# the roads connecting 13th node to 19th node are:
# [[13, 14, 3, 19]]
# the roads connecting 14th node to 15th node are:
# [[14, 3, 19, 15]]
# the roads connecting 14th node to 17th node are:
# [[14, 3, 17]]
# the roads connecting 14th node to 19th node are:
# [[14, 3, 19]]
# the roads connecting 16th node to 15th node are:
# [[16, 6, 15]]
# the roads connecting 18th node to 15th node are:
# [[18, 0, 15], [18, 6, 15]]
# the roads connecting 19th node to 15th node are:
# [[19, 15]]
# Rsquare score with all features: 0.8357783356884068
# Rsquare Score with selected features: 0.6545064443741117
# n_features= 3
# target= 0
# selected= [10, 15, 18]
# Rsquare score with all features: 0.8906375742676519
# Rsquare Score with selected features: 0.8136572203037149
# n_features= 3
# target= 3
# selected= [11, 17, 19]
# Rsquare score with all features: 0.7484522291134297
# Rsquare Score with selected features: 0.5135787214210674
# n_features= 3
# target= 5
# selected= [7, 9, 10]
# Rsquare score with all features: 0.8444306971543049
# Rsquare Score with selected features: 0.6785781654546112
# n_features= 3
# target= 6
# selected= [10, 16, 18]
# Rsquare score with all features: 0.7621441825832312
# Rsquare Score with selected features: 0.6704183325474209
# n_features= 2
# target= 9
# selected= [8, 10]
# Rsquare score with all features: 0.9069319942343388
# Rsquare Score with selected features: 0.7361900978920607
# n_features= 2
# target= 10
# selected= [9, 18]
# Rsquare score with all features: 0.7043764948552695
# Rsquare Score with selected features: 0.5627632409376132
# n_features= 2
# target= 11
# selected= [2, 3]
# Rsquare score with all features: 0.6542762939179603
# Rsquare Score with selected features: 0.4684965593709712
# n_features= 2
# target= 12
# selected= [6, 15]
# Rsquare score with all features: 0.7549388693848504
# Rsquare Score with selected features: 0.5019596310047283
# n_features= 2
# target= 13
# selected= [10, 14]
# Rsquare score with all features: 0.7701373389788814
# Rsquare Score with selected features: 0.7665344857430879
# n_features= 2
# target= 14
# selected= [3, 13]
# Rsquare score with all features: 0.929469331004017
# Rsquare Score with selected features: 0.8527973005129282
# n_features= 5
# target= 15
# selected= [0, 3, 6, 12, 19]
# Rsquare score with all features: 0.8888603574106579
# Rsquare Score with selected features: 0.8322771298781177
# n_features= 3
# target= 18
# selected= [6, 10, 16]
# Rsquare score with all features: 0.8460913283731223
# Rsquare Score with selected features: 0.6779563795933988
# n_features= 2
# target= 19
# selected= [3, 11]
# Rsquare score with all features: 0.8906375742676519
# Rsquare Score with selected features: 0.8129691615395976
# n_features= 2
# target= 3
# selected= [17, 19]
# Rsquare score with all features: 0.7621441825832312
# Rsquare Score with selected features: 0.6704183325474209
# n_features= 2
# target= 9
# selected= [8, 10]
# Rsquare score with all features: 0.9069319942343388
# Rsquare Score with selected features: 0.7361900978920607
# n_features= 2
# target= 10
# selected= [9, 18]
# Rsquare score with all features: 0.7701373389788814
# Rsquare Score with selected features: 0.7665344857430879
# n_features= 2
# target= 14
# selected= [3, 13]
# Rsquare score with all features: 0.929469331004017
# Rsquare Score with selected features: 0.7487337110339715
# n_features= 4
# target= 15
# selected= [3, 6, 12, 19]
# Rsquare score with all features: 0.8888603574106579
# Rsquare Score with selected features: 0.6547908137993722
# n_features= 2
# target= 18
# selected= [10, 16]
# Rsquare score with all features: 0.7621441825832312
# Rsquare Score with selected features: 0.6704183325474209
# n_features= 2
# target= 9
# selected= [8, 10]
# Rsquare score with all features: 0.7549388693848504
# Rsquare Score with selected features: 0.5019596310047283
# n_features= 2
# target= 13
# selected= [10, 14]
# Rsquare score with all features: 0.929469331004017
# Rsquare Score with selected features: 0.3029630263285241
# n_features= 2
# target= 15
# selected= [3, 12]
# ccccccccccc= 7
# 20  node 20  edges
# children_dic:
# {'0': [], '1': [], '2': [1, 15], '3': [1, 7], '4': [6], '5': [3], '6': [], '7': [6, 14], '8': [5], '9': [4, 5, 19], '10': [], '11': [14, 17], '12': [16], '13': [6, 14], '14': [19], '15': [], '16': [], '17': [7], '18': [12], '19': []}
# parents_dic:
# {'0': [], '1': [2, 3], '2': [], '3': [5], '4': [9], '5': [8, 9], '6': [4, 7, 13], '7': [3, 17], '8': [], '9': [], '10': [], '11': [], '12': [18], '13': [], '14': [7, 11, 13], '15': [2], '16': [12], '17': [11], '18': [], '19': [9, 14]}
# topological order of the nodes:
# [0, 1, 15, 2, 6, 19, 14, 7, 3, 4, 5, 8, 9, 10, 17, 11, 16, 12, 13, 18]
# the roads connecting 2th node to 1th node are:
# [[2, 1]]
# the roads connecting 3th node to 1th node are:
# [[3, 1]]
# the roads connecting 5th node to 1th node are:
# [[5, 3, 1]]
# the roads connecting 8th node to 1th node are:
# [[8, 5, 3, 1]]
# the roads connecting 9th node to 1th node are:
# [[9, 5, 3, 1]]
# the roads connecting 2th node to 15th node are:
# [[2, 15]]
# the roads connecting 5th node to 3th node are:
# [[5, 3]]
# the roads connecting 3th node to 6th node are:
# [[3, 7, 6]]
# the roads connecting 3th node to 7th node are:
# [[3, 7]]
# the roads connecting 8th node to 3th node are:
# [[8, 5, 3]]
# the roads connecting 9th node to 3th node are:
# [[9, 5, 3]]
# the roads connecting 3th node to 14th node are:
# [[3, 7, 14]]
# the roads connecting 3th node to 19th node are:
# [[3, 7, 14, 19]]
# the roads connecting 4th node to 6th node are:
# [[4, 6]]
# the roads connecting 9th node to 4th node are:
# [[9, 4]]
# the roads connecting 5th node to 6th node are:
# [[5, 3, 7, 6]]
# the roads connecting 5th node to 7th node are:
# [[5, 3, 7]]
# the roads connecting 8th node to 5th node are:
# [[8, 5]]
# the roads connecting 9th node to 5th node are:
# [[9, 5]]
# the roads connecting 5th node to 14th node are:
# [[5, 3, 7, 14]]
# the roads connecting 5th node to 19th node are:
# ...
# [[16, 3]]
# the roads connecting 4th node to 10th node are:
# [[4, 10]]
# the roads connecting 4th node to 13th node are:
# [[4, 10, 15, 13]]
# the roads connecting 4th node to 15th node are:
# [[4, 10, 15]]
# the roads connecting 5th node to 8th node are:
# [[5, 8]]
# the roads connecting 5th node to 13th node are:
# [[5, 15, 13]]
# the roads connecting 5th node to 15th node are:
# [[5, 15]]
# the roads connecting 5th node to 18th node are:
# [[5, 8, 18]]
# the roads connecting 6th node to 13th node are:
# [[6, 15, 13]]
# the roads connecting 6th node to 15th node are:
# [[6, 15]]
# the roads connecting 7th node to 10th node are:
# [[7, 10]]
# the roads connecting 7th node to 13th node are:
# [[7, 10, 15, 13], [7, 13], [7, 17, 15, 13]]
# the roads connecting 7th node to 15th node are:
# [[7, 10, 15], [7, 17, 15]]
# the roads connecting 7th node to 17th node are:
# [[7, 17]]
# the roads connecting 8th node to 18th node are:
# [[8, 18]]
# the roads connecting 10th node to 13th node are:
# [[10, 15, 13]]
# the roads connecting 10th node to 15th node are:
# [[10, 15]]
# the roads connecting 11th node to 13th node are:
# [[11, 13]]
# the roads connecting 15th node to 13th node are:
# [[15, 13]]
# the roads connecting 16th node to 13th node are:
# [[16, 3, 13], [16, 13]]
# the roads connecting 17th node to 13th node are:
# [[17, 15, 13]]
# the roads connecting 17th node to 15th node are:
# [[17, 15]]
# Rsquare score with all features: 0.8078064920980577
# Rsquare Score with selected features: 0.5066267746294169
# n_features= 3
# target= 0
# selected= [3, 7, 10]
# Rsquare score with all features: 0.6513784471342541
# Rsquare Score with selected features: 0.6491278879441502
# n_features= 2
# target= 1
# selected= [5, 14]
# Rsquare score with all features: 0.8317072398314093
# Rsquare Score with selected features: 0.3517204058105331
# n_features= 3
# target= 3
# selected= [0, 7, 11]
# Rsquare score with all features: 0.7674240581602645
# Rsquare Score with selected features: 0.6815030761207579
# n_features= 2
# target= 4
# selected= [0, 10]
# Rsquare score with all features: 0.8699538731365745
# Rsquare Score with selected features: 0.3371625152634815
# n_features= 3
# target= 5
# selected= [7, 10, 15]
# Rsquare score with all features: 0.8805231288358075
# Rsquare Score with selected features: 0.5777610400745279
# n_features= 3
# target= 7
# selected= [5, 10, 17]
# Rsquare score with all features: 0.8324625278632426
# Rsquare Score with selected features: 0.8326134732255561
# n_features= 2
# target= 8
# selected= [5, 18]
# Rsquare score with all features: 0.9185210234516791
# Rsquare Score with selected features: 0.2301287601894284
# n_features= 3
# target= 10
# selected= [5, 7, 17]
# Rsquare score with all features: 0.9011902263938212
# Rsquare Score with selected features: 0.6169540407127967
# n_features= 5
# target= 13
# selected= [5, 7, 11, 16, 17]
# Rsquare score with all features: 0.9590388268425474
# Rsquare Score with selected features: 0.9210446949800264
# n_features= 6
# target= 15
# selected= [0, 5, 6, 7, 10, 17]
# Rsquare score with all features: 0.6846999567684193
# Rsquare Score with selected features: 0.0013306331720405185
# n_features= 2
# target= 16
# selected= [7, 11]
# Rsquare score with all features: 0.837453973356912
# Rsquare Score with selected features: 0.5090864556042165
# n_features= 2
# target= 17
# selected= [7, 10]
# Rsquare score with all features: 0.8078064920980577
# Rsquare Score with selected features: 0.3146589756908623
# n_features= 2
# target= 0
# selected= [7, 10]
# Rsquare score with all features: 0.6513784471342541
# Rsquare Score with selected features: 0.6491278879441502
# n_features= 2
# target= 1
# selected= [5, 14]
# Rsquare score with all features: 0.8699538731365745
# Rsquare Score with selected features: 1.1102230246251565e-16
# n_features= 2
# target= 5
# selected= [7, 10]
# Rsquare score with all features: 0.9185210234516791
# Rsquare Score with selected features: 0.22974159151802176
# n_features= 2
# target= 10
# selected= [7, 17]
# Rsquare score with all features: 0.9011902263938212
# Rsquare Score with selected features: 0.8086076497536729
# n_features= 6
# target= 13
# selected= [3, 5, 7, 11, 16, 17]
# Rsquare score with all features: 0.9590388268425474
# Rsquare Score with selected features: 0.5187890055942744
# n_features= 2
# target= 15
# selected= [7, 10]
# Rsquare score with all features: 0.6513784471342541
# Rsquare Score with selected features: 0.6491278879441502
# n_features= 2
# target= 1
# selected= [5, 14]
# Rsquare score with all features: 0.9011902263938212
# Rsquare Score with selected features: 0.6165353845586858
# n_features= 3
# target= 13
# selected= [7, 11, 16]
# ccccccccccc= 98
# 20  node 20  edges
# children_dic:
# {'0': [], '1': [6, 7, 16], '2': [10], '3': [], '4': [0], '5': [13, 14, 18], '6': [16], '7': [], '8': [], '9': [12], '10': [6], '11': [1, 4, 10], '12': [17], '13': [], '14': [1], '15': [0], '16': [], '17': [16], '18': [3], '19': [4]}
# parents_dic:
# {'0': [4, 15], '1': [11, 14], '2': [], '3': [18], '4': [11, 19], '5': [], '6': [1, 10], '7': [1], '8': [], '9': [], '10': [2, 11], '11': [], '12': [9], '13': [5], '14': [5], '15': [], '16': [1, 6, 17], '17': [12], '18': [5], '19': []}
# topological order of the nodes:
# [0, 16, 6, 7, 1, 10, 2, 3, 4, 13, 14, 18, 5, 8, 17, 12, 9, 11, 15, 19]
# the roads connecting 4th node to 0th node are:
# [[4, 0]]
# the roads connecting 11th node to 0th node are:
# [[11, 4, 0]]
# the roads connecting 15th node to 0th node are:
# [[15, 0]]
# the roads connecting 19th node to 0th node are:
# [[19, 4, 0]]
# the roads connecting 5th node to 1th node are:
# [[5, 14, 1]]
# the roads connecting 1th node to 6th node are:
# [[1, 6]]
# the roads connecting 1th node to 7th node are:
# [[1, 7]]
# the roads connecting 11th node to 1th node are:
# [[11, 1]]
# the roads connecting 14th node to 1th node are:
# [[14, 1]]
# the roads connecting 1th node to 16th node are:
# [[1, 6, 16], [1, 16]]
# the roads connecting 2th node to 6th node are:
# [[2, 10, 6]]
# the roads connecting 2th node to 10th node are:
# [[2, 10]]
# the roads connecting 2th node to 16th node are:
# [[2, 10, 6, 16]]
# the roads connecting 5th node to 3th node are:
# [[5, 18, 3]]
# the roads connecting 18th node to 3th node are:
# [[18, 3]]
# the roads connecting 11th node to 4th node are:
# [[11, 4]]
# the roads connecting 19th node to 4th node are:
# [[19, 4]]
# the roads connecting 5th node to 6th node are:
# [[5, 14, 1, 6]]
# the roads connecting 5th node to 7th node are:
# [[5, 14, 1, 7]]
# the roads connecting 5th node to 13th node are:
# [[5, 13]]
# the roads connecting 5th node to 14th node are:
# [[5, 14]]
# the roads connecting 5th node to 16th node are:
# [[5, 14, 1, 6, 16], [5, 14, 1, 16]]
# the roads connecting 5th node to 18th node are:
# [[5, 18]]
# the roads connecting 10th node to 6th node are:
# [[10, 6]]
# the roads connecting 11th node to 6th node are:
# [[11, 1, 6], [11, 10, 6]]
# the roads connecting 14th node to 6th node are:
# [[14, 1, 6]]
# the roads connecting 6th node to 16th node are:
# [[6, 16]]
# the roads connecting 11th node to 7th node are:
# [[11, 1, 7]]
# the roads connecting 14th node to 7th node are:
# [[14, 1, 7]]
# the roads connecting 9th node to 12th node are:
# [[9, 12]]
# the roads connecting 9th node to 16th node are:
# [[9, 12, 17, 16]]
# the roads connecting 9th node to 17th node are:
# [[9, 12, 17]]
# the roads connecting 11th node to 10th node are:
# [[11, 10]]
# the roads connecting 10th node to 16th node are:
# [[10, 6, 16]]
# the roads connecting 11th node to 16th node are:
# [[11, 1, 6, 16], [11, 1, 16], [11, 10, 6, 16]]
# the roads connecting 12th node to 16th node are:
# [[12, 17, 16]]
# the roads connecting 12th node to 17th node are:
# [[12, 17]]
# the roads connecting 14th node to 16th node are:
# [[14, 1, 6, 16], [14, 1, 16]]
# the roads connecting 17th node to 16th node are:
# [[17, 16]]
# Rsquare score with all features: 0.667961860966938
# Rsquare Score with selected features: 0.34621493666420655
# n_features= 2
# target= 0
# selected= [11, 15]
# Rsquare score with all features: 0.9213027418638252
# Rsquare Score with selected features: 0.88394707008195
# n_features= 5
# target= 1
# selected= [7, 11, 14, 16, 17]
# Rsquare score with all features: 0.8223932951761578
# Rsquare Score with selected features: 0.7626334733698216
# n_features= 3
# target= 4
# selected= [0, 11, 19]
# Rsquare score with all features: 0.8539972922136021
# Rsquare Score with selected features: 0.770021432948635
# n_features= 3
# target= 5
# selected= [13, 14, 18]
# Rsquare score with all features: 0.9091142675232707
# Rsquare Score with selected features: 0.8531353292864524
# n_features= 3
# target= 6
# selected= [2, 10, 16]
# Rsquare score with all features: 0.8419535452468753
# Rsquare Score with selected features: 0.765859586868283
# n_features= 3
# target= 10
# selected= [2, 6, 11]
# Rsquare score with all features: 0.8409643863954063
# Rsquare Score with selected features: 0.603985746088626
# n_features= 3
# target= 11
# selected= [1, 4, 10]
# Rsquare score with all features: 0.822834489911626
# Rsquare Score with selected features: 0.7419824827511241
# n_features= 2
# target= 12
# selected= [9, 17]
# Rsquare score with all features: 0.7787164931056973
# Rsquare Score with selected features: 0.5013962330646091
# n_features= 2
# target= 14
# selected= [5, 11]
# Rsquare score with all features: 0.9394789339933013
# Rsquare Score with selected features: 0.9018602834314281
# n_features= 3
# target= 16
# selected= [1, 6, 17]
# Rsquare score with all features: 0.8164018603171492
# Rsquare Score with selected features: 0.6460064217348286
# n_features= 2
# target= 17
# selected= [1, 12]
# Rsquare score with all features: 0.7626230339552292
# Rsquare Score with selected features: 0.7621930630693045
# n_features= 2
# target= 18
# selected= [3, 5]
# Rsquare score with all features: 0.667961860966938
# Rsquare Score with selected features: 0.34621493666420655
# n_features= 2
# target= 0
# selected= [11, 15]
# Rsquare score with all features: 0.9213027418638252
# Rsquare Score with selected features: 0.7904027988919389
# n_features= 2
# target= 1
# selected= [7, 11]
# Rsquare score with all features: 0.8539972922136021
# Rsquare Score with selected features: 0.6640067361304454
# n_features= 2
# target= 5
# selected= [14, 18]
# Rsquare score with all features: 0.9091142675232707
# Rsquare Score with selected features: 0.8531353292864524
# n_features= 3
# target= 6
# selected= [2, 10, 16]
# Rsquare score with all features: 0.7653846173099861
# Rsquare Score with selected features: 0.7658322911864466
# n_features= 2
# target= 7
# selected= [1, 15]
# Rsquare score with all features: 0.8409643863954063
# Rsquare Score with selected features: 0.6718375675227615
# n_features= 4
# target= 11
# selected= [1, 2, 4, 10]
# Rsquare score with all features: 0.7787164931056973
# Rsquare Score with selected features: 0.7772172287833947
# n_features= 3
# target= 14
# selected= [1, 5, 11]
# Rsquare score with all features: 0.9394789339933013
# Rsquare Score with selected features: 0.9390734679878974
# n_features= 5
# target= 16
# selected= [1, 6, 12, 14, 17]
# Rsquare score with all features: 0.8539972922136021
# Rsquare Score with selected features: 0.770021432948635
# n_features= 3
# target= 5
# selected= [13, 14, 18]
# Rsquare score with all features: 0.9394789339933013
# Rsquare Score with selected features: 0.9390734679878974
# n_features= 5
# target= 16
# selected= [1, 6, 12, 14, 17]
# ccccccccccc= 99
# 20  node 20  edges
# children_dic:
# {'0': [3], '1': [3, 8, 14], '2': [5, 7], '3': [], '4': [5], '5': [3], '6': [], '7': [], '8': [], '9': [5], '10': [14], '11': [15], '12': [4], '13': [4, 5, 14], '14': [3], '15': [], '16': [3], '17': [0], '18': [], '19': [5, 13]}
# parents_dic:
# {'0': [17], '1': [], '2': [], '3': [0, 1, 5, 14, 16], '4': [12, 13], '5': [2, 4, 9, 13, 19], '6': [], '7': [2], '8': [1], '9': [], '10': [], '11': [], '12': [], '13': [19], '14': [1, 10, 13], '15': [11], '16': [], '17': [], '18': [], '19': []}
# topological order of the nodes:
# [3, 0, 8, 14, 1, 5, 7, 2, 4, 6, 9, 10, 15, 11, 12, 13, 16, 17, 18, 19]
# the roads connecting 0th node to 3th node are:
# [[0, 3]]
# the roads connecting 17th node to 0th node are:
# [[17, 0]]
# the roads connecting 1th node to 3th node are:
# [[1, 3], [1, 14, 3]]
# the roads connecting 1th node to 8th node are:
# [[1, 8]]
# the roads connecting 1th node to 14th node are:
# [[1, 14]]
# the roads connecting 2th node to 3th node are:
# [[2, 5, 3]]
# the roads connecting 2th node to 5th node are:
# [[2, 5]]
# the roads connecting 2th node to 7th node are:
# [[2, 7]]
# the roads connecting 4th node to 3th node are:
# [[4, 5, 3]]
# the roads connecting 5th node to 3th node are:
# [[5, 3]]
# the roads connecting 9th node to 3th node are:
# [[9, 5, 3]]
# the roads connecting 10th node to 3th node are:
# [[10, 14, 3]]
# the roads connecting 12th node to 3th node are:
# [[12, 4, 5, 3]]
# the roads connecting 13th node to 3th node are:
# [[13, 4, 5, 3], [13, 5, 3], [13, 14, 3]]
# the roads connecting 14th node to 3th node are:
# [[14, 3]]
# the roads connecting 16th node to 3th node are:
# [[16, 3]]
# the roads connecting 17th node to 3th node are:
# [[17, 0, 3]]
# the roads connecting 19th node to 3th node are:
# [[19, 5, 3], [19, 13, 4, 5, 3], [19, 13, 5, 3], [19, 13, 14, 3]]
# the roads connecting 4th node to 5th node are:
# [[4, 5]]
# the roads connecting 12th node to 4th node are:
# [[12, 4]]
# the roads connecting 13th node to 4th node are:
# [[13, 4]]
# the roads connecting 19th node to 4th node are:
# [[19, 13, 4]]
# the roads connecting 9th node to 5th node are:
# [[9, 5]]
# the roads connecting 12th node to 5th node are:
# [[12, 4, 5]]
# the roads connecting 13th node to 5th node are:
# [[13, 4, 5], [13, 5]]
# the roads connecting 19th node to 5th node are:
# [[19, 5], [19, 13, 4, 5], [19, 13, 5]]
# the roads connecting 10th node to 14th node are:
# [[10, 14]]
# the roads connecting 11th node to 15th node are:
# [[11, 15]]
# the roads connecting 13th node to 14th node are:
# [[13, 14]]
# the roads connecting 19th node to 13th node are:
# [[19, 13]]
# the roads connecting 19th node to 14th node are:
# [[19, 13, 14]]
# Rsquare score with all features: 0.7695340816257429
# Rsquare Score with selected features: 0.30900203256334735
# n_features= 2
# target= 0
# selected= [3, 13]
# Rsquare score with all features: 0.65333015880248
# Rsquare Score with selected features: 0.5792903292422713
# n_features= 3
# target= 1
# selected= [8, 10, 14]
# Rsquare score with all features: 0.7438152916339806
# Rsquare Score with selected features: 0.0038504952675539883
# n_features= 2
# target= 2
# selected= [4, 13]
# Rsquare score with all features: 0.8702205112659661
# Rsquare Score with selected features: 0.6655610075875114
# n_features= 5
# target= 3
# selected= [0, 9, 13, 14, 16]
# Rsquare score with all features: 0.8843940810524825
# Rsquare Score with selected features: 0.6568708019965557
# n_features= 3
# target= 4
# selected= [2, 5, 9]
# Rsquare score with all features: 0.9488030048545243
# Rsquare Score with selected features: 0.8963178093511507
# n_features= 6
# target= 5
# selected= [0, 2, 4, 9, 10, 13]
# Rsquare score with all features: 0.9415060468880697
# Rsquare Score with selected features: 0.6793850507283287
# n_features= 4
# target= 13
# selected= [5, 9, 10, 14]
# Rsquare score with all features: 0.9055430676193807
# Rsquare Score with selected features: 0.7695145268438758
# n_features= 4
# target= 14
# selected= [0, 3, 10, 13]
# Rsquare score with all features: 0.6803597715906863
# Rsquare Score with selected features: 0.6106357010607193
# n_features= 2
# target= 19
# selected= [4, 13]
# Rsquare score with all features: 0.8702205112659661
# Rsquare Score with selected features: 0.7766535110777906
# n_features= 8
# target= 3
# selected= [0, 2, 5, 9, 10, 13, 14, 16]
# Rsquare score with all features: 0.8843940810524825
# Rsquare Score with selected features: 0.6054656246119032
# n_features= 2
# target= 4
# selected= [2, 5]
# Rsquare score with all features: 0.9488030048545243
# Rsquare Score with selected features: 0.649637758997043
# n_features= 3
# target= 5
# selected= [2, 9, 13]
# Rsquare score with all features: 0.9415060468880697
# Rsquare Score with selected features: 0.0
# n_features= 2
# target= 13
# selected= [9, 10]
# Rsquare score with all features: 0.6803597715906863
# Rsquare Score with selected features: 0.6747802056072773
# n_features= 4
# target= 19
# selected= [4, 11, 12, 13]
# Rsquare score with all features: 0.8702205112659661
# Rsquare Score with selected features: 0.5260810975180794
# n_features= 3
# target= 3
# selected= [0, 13, 14]
# Rsquare score with all features: 0.6803597715906863
# Rsquare Score with selected features: 0.6106357010607193
# n_features= 2
# target= 19
# selected= [4, 13]

# %%
len(result)
# Out:
# 2374

# %%
fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)

axs[0].hist(result[], bins=n_bins)
axs[1].hist(y, bins=n_bins)
# Out:
# (0, 3, [6, 12, 14], 3, 1, 0.8340858170084281, 0.7651641164825633)

# %%
ss1_1=[res[5] for res in result if res[4]==1]
ss1_2=[res[5] for res in result if res[4]==2]
ss1_3=[res[5] for res in result if res[4]==3]

ss2_1=[res[6] for res in result if res[4]==1]
ss2_2=[res[6] for res in result if res[4]==2]
ss2_3=[res[6] for res in result if res[4]==3]

# %%
len(ss2)
# Out:
# 1194

# %%
n_bins=50
fig, axs = plt.subplots(3, 2, sharey=True, tight_layout=True)
s=axs[0,0].hist(ss2_1, bins=n_bins)
s=axs[1,0].hist(ss2_2, bins=n_bins)
s=axs[2,0].hist(ss2_3, bins=n_bins)

s=axs[0,1].hist(ss1_1, bins=n_bins)
s=axs[1,1].hist(ss1_2, bins=n_bins)
s=axs[2,1].hist(ss1_3, bins=n_bins)
# Out:
# /Users/jyj/anaconda3/envs/PythonData/lib/python3.6/site-packages/matplotlib/figure.py:2362: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %% [markdown]
# ## Some notes:
# - We found interesting examples for featuer selection in many Graphs(presented only one on above). These findings are easy to interpret by father-child or child-father relations.
# - In our ensemble study based on 100 graphs, simple histogram doens't provide meaniful results(at least not understood well for now).
# - In our ensembale cauculation, for a general node i,  the distance L (1,or 2 or 3) measures the distance between the given  node to other nodes that are connected by father-child or child-father relation. For a given L and i, we can count the number of L-distant neibours. We input this number as the the number of features to be selected. In many cases(contrary to the specific example discussed on above),  the features selected by sklearn.feature_selection.SelectFromModel is not the features we count.
#
# - We may try different way, e.g., force the selected features to be the ones we want to choose by simple counting, or, by counting the neighbours by <=L instead of =L. Possibly, we should differentiate father-child and child-father relation.
